# %%
#Installing ultralytics
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.9/605.9 kB 6.1 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# !cd yolov5
pip install -r yolov5/requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15814, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 15814 (delta 9), reused 27 (delta 9), pack-reused 15768
# Receiving objects: 100% (15814/15814), 14.64 MiB | 15.55 MiB/s, done.
# Resolving deltas: 100% (10821/10821), done.

# %%
#Unzipping train, valid and test folders
# !unzip /content/yolov5/train.zip
# !unzip /content/yolov5/valid.zip
# !unzip /content/yolov5/test.zip
# Out:
# Archive:  /content/yolov5/valid.zip
#    creating: valid/
#    creating: valid/images/
#   inflating: valid/images/val_00000_png.rf.b03be11c895f0ed0a48dbe327248d7ed.jpg
#   inflating: valid/images/val_00001_png.rf.71c61596f49aedc1bd71e6f225c6dd76.jpg
#   inflating: valid/images/val_00002_png.rf.a9fc2193fb8be3e6c03ce66d2b4dc63a.jpg
#   inflating: valid/images/val_00003_png.rf.65e027f021551f9e4f735f187c001ff9.jpg
#   inflating: valid/images/val_00004_png.rf.700ddb8254a0f912c8fd87f946d591a4.jpg
#   inflating: valid/images/val_00005_png.rf.f937595d7aa54b09888a6931634b7853.jpg
#   inflating: valid/images/val_00006_png.rf.6b377658be6c0b8c98488e0318949303.jpg
#   inflating: valid/images/val_00007_png.rf.456e58a961d8c63932d7952c5b145a90.jpg
#   inflating: valid/images/val_00008_png.rf.7401853bf6584dbaee2a6c6158589e01.jpg
#   inflating: valid/images/val_00009_png.rf.1fdf4d875280dd578163157f326899c6.jpg
#   inflating: valid/images/val_00010_png.rf.25362217a4f98cb1bd38f83683e04036.jpg
# ...

# %%
#Running object detection using yolov5s.pt
# !python detect.py --weights yolov5s.pt --img 4999 --conf 0.25 --source train/images
# Out:
# detect: weights=['yolov5s.pt'], source=train/images, data=data/coco128.yaml, imgsz=[4999, 4999], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-193-g485da42 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 53.7MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ --img-size [4999, 4999] must be multiple of max stride 32, updating to [5024, 5024]
# image 1/4994 /content/yolov5/train/images/train_00000_png.rf.fa5aad2f1a51a0e4dc2b6e433fb34df8.jpg: 5024x5024 (no detections), 32963.6ms
# ...

# %%
#Training the model on cichlid dataset
# !python /content/yolov5/train.py --img 512 --batch 24 --epochs 200 --cfg /content/yolov5/models/yolov5s.yaml --data /content/yolov5/data.yaml  --weights /content/yolov5/yolov5s.pt  --hyp /content/yolov5/data/hyps/hyp.no-augmentation.yaml
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")
#
# ...

# %%
# Out:
# '/device:GPU:0'
